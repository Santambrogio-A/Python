# %%
import pymongo 
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")

db = client['4E']

# %%
db.impianti.find_one()
# Out:
# {'ID_NIL': 1,
#  'INDIRIZZO': 'Corso DI PORTA VITTORIA 4',
#  'LAT_Y_WGS84': Decimal128('45.4622267523854'),
#  'LONG_X_WGS84': Decimal128('9.19750817181182'),
#  'Location': '(45.4622267523854, 9.19750817181182)',
#  'MUNICIPIO': 1,
#  'NIL': 'DUOMO',
#  'Sit_NomeImpianto': 'SEDE SIGNORA',
#  'Sit_NomeVia': 'DI PORTA VITTORIA',
#  'Sit_NumCiv': 4,
#  'Sit_StatoImpianto': 'Acceso',
#  'Ti_TipoImpianto': 'Altro',
#  'Tv_TipoVia': 'Corso',
#  '_id': ObjectId('623ca29cf224e8f68db4a268'),
#  'gestore': 'A2A S.p.A.'}

# %% [markdown]
# # l’elenco degli impianti accesi. Visualizzare solo il nome e l’indirizzo

# %%
result = db.impianti.find({"Sit_StatoImpianto":{"$regex": "Acceso"}},
                           {"INDIRIZZO": 1, "Sit_NomeImpianto": 1, "_id": 0})
df = pd.DataFrame(list(result))
df
# Out:
#                                        Sit_NomeImpianto  \
# 0                                          SEDE SIGNORA
# 1     TELESPAZIO S.p.a. - PONTE RADIO TV MILANO/CAMP...
# 2                                             FAMAGOSTA
# 3                                            RIC. OVEST
# 4                                        MI ROGOREDO WS
# ...                                                 ...
# 1783                                           BRUZZANO
# 1784                                             RETE 4
# 1785                                        San Galdino
# 1786                              MILANO CORSO SEMPIONE
# 1787                                     CORSO SEMPIONE
#
#                       INDIRIZZO
# 0     Corso DI PORTA VITTORIA 4
# 1             Corso SEMPIONE 27
# 2                 Via PALATUCCI
# 3               Via PIANELLA 10
# 4             Via MONTE PIANA 7
# ...                         ...
# 1783             Via GALIANI 12
# ...

# %% [markdown]
# # gli indirizzi in cui si trovano gli impianti dell’ATM

# %%
result = db.impianti.find({"gestore":{"$regex": "A.T.M."}},
                           {"INDIRIZZO": 1, "gestore": 1, "_id": 0})
df = pd.DataFrame(list(result))
df
# Out:
#                                          gestore  \
# 0   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 1   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 2                    LATTEMIELE LOMBARDIA S.r.l.
# 3   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 4                    LATTEMIELE LOMBARDIA S.r.l.
# 5                    LATTEMIELE LOMBARDIA S.r.l.
# 6   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 7   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 8   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 9   A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 10  A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 11  A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 12  A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
# 13  A.T.M. - AZIENDA TRASPORTI MUNICIPALI S.p.A.
#
#                                 INDIRIZZO
# 0                           Via PALATUCCI
# 1   Località PARCHEGGIO ATM CASCINA GOBBA
# 2                        Piazza GRAMSCI 2
# 3                           Via PALATUCCI
# ...

# %% [markdown]
# # l’elenco degli impianti della Vodafone e della TIM

# %%
result = db.impianti.find({'$or': [{"gestore" : {"$regex": "TIM"}} , {"gestore" :{"$regex": "VODAFONE"}}]})
df = pd.DataFrame(list(result))
df
# Out:
#                           _id       Sit_NomeImpianto     gestore  \
# 0    623ca29cf224e8f68db4a274    MI RIPAMONTI IEO MC  TIM S.p.A.
# 1    623ca29cf224e8f68db4a28c            VF FLAGSHIP    VODAFONE
# 2    623ca29cf224e8f68db4a296       MI S.GOTTARDO MC  TIM S.p.A.
# 3    623ca29cf224e8f68db4a29b           MI ISONZO MC  TIM S.p.A.
# 4    623ca29cf224e8f68db4a2b0   EXPO DARSENA NAVIGLI    VODAFONE
# ..                        ...                    ...         ...
# 728  623ca29df224e8f68db4a8d6  CASCINA SAN ROMANELLO    VODAFONE
# 729  623ca29df224e8f68db4a8ef              MI LAMBRO  TIM S.p.A.
# 730  623ca29df224e8f68db4a8f4            MONTECENERI    VODAFONE
# 731  623ca29df224e8f68db4a908          VIA DE PREDIS    VODAFONE
# 732  623ca29df224e8f68db4a930               BRUZZANO    VODAFONE
#
#     Ti_TipoImpianto Sit_StatoImpianto   Tv_TipoVia      Sit_NomeVia  \
# 0        Microcella            Acceso          Via        RIPAMONTI
# ...

# %% [markdown]
# # gli indirizzi in cui c’è più di un impianto
